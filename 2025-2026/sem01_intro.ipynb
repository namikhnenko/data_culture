# %% [markdown]
# # Семинар 1: знакомство с Jupyter Notebook, арифметические операции, базовые типы данных в Python, условные конструкции

# %% [markdown]
# ‼️ **Важно** ‼️
#
#
# 1.   Формула оценки: 0.15 х активность на семинарах + 0.2 х самостоятельные работы + 0.2 х контрольная работа + 0.25 х проект + 0.2 х экзамен, затем домножаем на 0.9 и берем минимум из 8 и оценки
# 2.   За семинары предусмотрена оценка за активность, активность = решаем задачки с пояснениями, участвуем в обсуждениях
# 3.   Блокирующих форм контроля сейчас нет
# 4.   ПУД лежит [тут](https://www.hse.ru/edu/courses/1079999875)
# 5.   Все работы проводятся с использованием SafeExam браузером и дополнительной камерой
# 6.   Навигация по контрольной работе будет несвободной, т е к предыдущим заданим возвращаться нельзя
# 7.   Банк вопросов к НЭ есть в курсе в SmartLMS

# %% [markdown]
# Это Jupyter-ноутбук. Тут можно писать код прямо в ячейках и выполнять его пошагово. Это удобно и часто, например, используется в анализе данных. Тут можно *по-разному* **форматировать** ~текст~. Можно запускать его со своего копьютера, если у вас есть соответствующая программа, или пользоваться онлайн-версией (например, [google colab](https://colab.google), в котором вы сейчас смотрите эту тетрадку). Мы в этом году джупитером скорее всего не будем пользоваться, но, возможно, некоторые конспекты с пар будут в таком формате.

# %% [markdown]
# Тут можно создавать ячейки, писать в них код и запускать их (с помощью кнопочки Run со стрекочкой вверху слева или shift+ctrl).

# %%
1
# Out:
# 1

# %%
2 + 5
# Out:
# 7

# %% [markdown]
# Всё работает, а мы заодно познакомились с операцией сложения. Посмотрим, что еще умеет питон и как это написать.

# %% [markdown]
# ## Арифметика

# %%
# умножение (да-да, с помощью решеточки в питоне можно писать комментарии)
3 * (2 + 5)
# Out:
# 21

# %%
# деление
18 / 7
# Out:
# 2.5714285714285716

# %%
# целочисленное деление (всё, что до запятой)
18 // 7
# Out:
# 2

# %%
# остаток от деления
18 % 7
# Out:
# 4

# %%
18 % -7
# Out:
# -3

# %%
# возведение в степень (осторожно! не ^)
2 ** 3

# %%
abs(1 - 3)
# Out:
# 2

# %%
import math

math.log(8, 2)
# Out:
# 3.0

# %% [markdown]
# ## Переменные

# %% [markdown]
# В python есть 2 типа сущностей: объекты и операции.
#
# Объекты существуют, операции их изменяют, перебирают, сохраняют или удаляют. Мы уже научились некоторым операциям. Теперь научимся сохранять результаты этих операций в переменые.

# %%
a = 2
b = 7
print(a, b, 5, "hello world")
# Out:
# 2 7 5 hello world

# %%
1euh = 1
# Out:
#   File "/tmp/ipython-input-3599015357.py", line 1
#     1euh = 1
#     ^
# SyntaxError: invalid decimal literal

# %%
x = 1
X = 2

print(X)
print(x)
# Out:
# 2
# 1

# %%
print(1)

# %% [markdown]
# Мы сохранили числовые значения в переменные и напечатали их с помощью функции `print()`. `a`, `b` в данном случае - это аргументы данной функции. Подробнее о `print()` еще поговорим дальше.

# %%
a + 3
# Out:
# 5

# %%
a / 5

# %%
print(a)
# Out:
# 2

# %% [markdown]
# Мы же добавили 3 к `a`, почему `a` всё ещё 2, а не 5? Потому что мы не сохранили значение выражения в переменную! Если хотим изменить именно `a`, можно записать это несколькими способами.

# %%
a = a + 2
# a += 2
# то же самое, только покороче записали, такая вот красота от питона
# перед = может быть любой арифм знак с той же логикой

# %%
print(a)
# Out:
# 6

# %% [markdown]
# Вот теперь всё как надо.

# %% [markdown]
# ## Типы данных

# %% [markdown]
# У всех объектов в python есть тип/класс. Узнать его можно вот так.

# %%
type(a)
# Out:
# int

# %% [markdown]
# До сих пор мы заводили переменные с целочисленным типом (integer, int). Но во время операций нам так же встречались вещественные числа, или числа с плавающей точкой (float)

# %%
x = 5  # целое число
print(x, type(x))

z = 2.17  # вещественное число
print(z, type(z))
# Out:
# 5 <class 'int'>
# 2.17 <class 'float'>

# %% [markdown]
# Ещё в питоне есть сторки. Они оформляются в кавычки. Можно одинарные, можно двойные.

# %%
a = 'never'

# %%
type(a)
# Out:
# str

# %% [markdown]
# Важно: если у вас в строке присутствуют кавычки как часть строки, надо чтобы кавычки-элементы_строки и кавычки-оформители_строки были разные, иначе питон не будет вас понимать (см. подсветку) и будет ругаться.

# %%
x = 'Национальный исследовательский унивеситет "Высшая школа экономики"'
y = "Национальный исследовательский унивеситет 'Высшая школа экономики'"
q = 'Национальный исследовательский унивеситет 'Высшая школа экономики"'
# Out:
#   File "/tmp/ipython-input-502531464.py", line 3
#     q = 'Национальный исследовательский унивеситет 'Высшая школа экономики"'
#                                                                           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
x = 'Национальный исследовательский унивеситет "Высшая школа экономики"'
y = "Национальный исследовательский унивеситет 'Высшая школа экономики'"
q = 'Национальный исследовательский унивеситет \'Высшая школа экономики"'

# %%
print(q)
# Out:
# Национальный исследовательский унивеситет 'Высшая школа экономики"

# %% [markdown]
# *Вот так, кстати, выглядит ошибка. Ошибок бояться не надо! Они не кусаются (хотя нервы могут изрядно подпортить). Надо читать, что написано, и если непонятно, гуглить.*

# %% [markdown]
# Строки можно складывать, можно умножать. А вот возвести в степень уже не получится.

# %%
b = 'gonna'
c = 'give'
d = 'you'
e = 'up'

print(a + '.' + b + ' sdfhdsjghdsfg' + c + ' ' + d + ' ' + e) # hehe (' ' -- это строка, состоящая из одного пробела)
print(e * 4)
print(e ** 2)
# Out:
# never.gonna sdfhdsjghdsfggive you up
# upupupup
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1538990363.py in <cell line: 0>()
#       6 print(a + '.' + b + ' sdfhdsjghdsfg' + c + ' ' + d + ' ' + e) # hehe (' ' -- это строка, состоящая из одного пробела)
#       7 print(e * 4)
# ----> 8 print(e ** 2)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# Ещё раз: сложение строк и сложение чисел -- это про разное! Хоть и используется одинаковый значок.

# %%
print('1' + '2')
print(1 + 2)
# Out:
# 12
# 3

# %%
1 + '1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2877782753.py in <cell line: 0>()
# ----> 1 1 + '1'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
'1' + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1258136175.py in <cell line: 0>()
# ----> 1 '1' + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
'1' + str(1)
# Out:
# '11'

# %%
int("1") + 1
# Out:
# 2

# %%
int(10)
# Out:
# 10

# %%
int("abc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2151585967.py in <cell line: 0>()
# ----> 1 int("abc")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# Переменные можно сравнивать между собой. При этом получаем ответ - либо истина (True), либо ложь (False). И это новый тип данных - bool

# %%
c = 4
d = 7

# %%
# равенство (два знака равно! один это присваивание значения переменной)
c == d
# Out:
# False

# %%
# неравенство
c != d
# Out:
# True

# %%
not (c == d)
# Out:
# True

# %%
# больше (больше или равно >=)
c > d
# Out:
# False

# %%
# меньше (меньше или равно <=)
c < d
# Out:
# True

# %% [markdown]
# <table>
#     <tr>
#         <th>Оператор сравнения</th>
#         <th> Интерпретация </th>
#     </tr>
#     <tr><td>&lt;</td><td> Первый операнд меньше второго </td></tr>
#     <tr><td>&gt;</td><td> Первый операнд больше второго</td></tr>
#     <tr><td>&lt;=</td><td> Меньше или равно</td></tr>
#     <tr><td>&gt;=</td><td> Больше или равно</td></tr>
#     <tr><td>==</td><td> Два операнда равны </td></tr>
#     <tr><td>!=</td><td> Два операнда не равны</td></tr>
# </table>

# %%
0.1 + 0.2 == 0.3  # однако что?
# Out:
# False

# %%
0.5 + 0.25 == 0.75  # и снова однако что? но другое..
# Out:
# True

# %%
1e-6 # 0,000001

# %%
abs(0.1 + 0.2 - 0.3) == 0
# Out:
# False

# %% [markdown]
# Все типы данных, которые мы сейчас посмотрели - неизменяемые. Что это значит? Можно почитать [тут](https://github.com/aaparshina/PROG_23-24/blob/main/PROG_01_upd.ipynb). Сейчас достаточно знать, что если мы меняем значение одной переменной, значение другой от этого не поменяется:

# %%
X = 1           # пусть X ссылается на 1
Y = X           # а Y ссылается на X, то есть тоже на 1
print(X, Y)

X += 1          # попробуем изменить X, добавив к переменной 1
print(X, Y)
# Out:
# 1 1
# 2 1

# %% [markdown]
# ### Задача 1
#
# Напечатайте результаты сравнения следующих переменных:
#
# *   400 равно 40 * 10
# *   100 больше чем 400 - (100 * 2)
# *   300 больше или равно чем 300 + 1
# *   8 не равно 4 * 4 / 2
# *   21 меньше или равно чем 24 - 2
# *   с подвохом: 0.45 равно 0.15 + 0.3

# %%
2.5

# %%
2.49999999999

# %%
1/3

# %% [markdown]
# ## Вывод и ввод

# %% [markdown]
# Мы уже умеем выводить результат с помощью функции `print()`. У функций помимо **аргументов** (== с чем делать), у нее также есть **параметры** (== как делать). У функции `print()` есть, например, параметры `sep` и `end`. Попробуйте сами понять их значение и мотивацию названия из примеров ниже. А еще рекомендуется найти какие-нибудь другие параметры функции `print()` (зАгУгЛиВ) и поиграться с ними.

# %%
a, b, c, d, e = 1, 2, 3, 4, 5

# %%
print(1, end="\n")
print(2)
# Out:
# 1
# 2

# %%
print(a, b, c, d, e, sep='_', end='...')
print(1)
# Out:
# 1_2_3_4_5...1

# %%
print(a, b, c, d, e, sep=' ', end='!')
# Out:
# 1 2 3 4 5!

# %% [markdown]
# Теперь представим, что мы написали код, который спрашивает у пользователя логин и дальше что-то с ним делает. В этом нам помогает функция `input()`. При запуске кода надо ввести значение, тогда код будет работать дальше.

# %%
x = input()
print('Кто сегодня молодец? Ну, конечно,', x, end='!')
# Out:
# gyrjhsgb
# Кто сегодня молодец? Ну, конечно, gyrjhsgb!

# %%
# можно добавить пользователю подсказку
# которая при этом не будет записываться в переменную
x = input('Введите своё имя: ')
print('Кто сегодня молодец? Ну, конечно,', x, sep=' ', end='!')
# Out:
# Введите своё имя: 12
# Кто сегодня молодец? Ну, конечно, 12!

# %% [markdown]
# Важно: `input()` всегда принимает и возвращает строку.

# %%
hours = input('Введите количество часов, которое вы поработали сегодня: ')
minutes = hours * 60
print('Ого, вы поработали целых ', minutes, ' минут! Это много, можно и сериальчик посмотреть.')
# Out:
# Введите количество часов, которое вы поработали сегодня: 8
# Ого, вы поработали целых  888888888888888888888888888888888888888888888888888888888888  минут! Это много, можно и сериальчик посмотреть.

# %% [markdown]
# Поэтому, если нам нужно число, надо превратить строку в число. Сделать это можно с помощью функции `int()` (попробуйте сами догадаться, как превратить строку (тип str) в число).

# %%
hours = input('Введите количество часов, которое вы поработали сегодня: ')
hours = int(hours)
minutes = hours * 60
print('Ого, вы поработали целых ', minutes, ' минут! Это много, можно и сериальчик посмотреть.')
# Out:
# Введите количество часов, которое вы поработали сегодня: 8
# Ого, вы поработали целых  480  минут! Это много, можно и сериальчик посмотреть.

# %%
# а можно в одну строчку
hours = int(input('Введите количество часов, которое вы поработали сегодня: '))
minutes = hours * 60
print('Ого, вы поработали целых ', minutes, ' минут! Это много, можно и сериальчик посмотреть.')

# %%
a = int(input())
type(a)
# Out:
# 3
# int

# %%
a = float(input())

# %%
int('abc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-186767990.py in <cell line: 0>()
# ----> 1 int('abc')
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# ## Сложные логические выражения и условные конструкции

# %% [markdown]
# В Python 3 логических оператора:
#
# and — логическое "И" - True, если все части выражения True
#
# or — логическое "ИЛИ" - True, если хотя бы одна часть выражения True
#
# not — логическое отрицание - True, если исходное выражение False

# %%
print(not(True or True))
print(not(True or False))
print(not(False and True))
print(not(False and False))
# Out:
# False
# False
# True
# True

# %% [markdown]
# Программы, которые мы видели раньше, имели линейную структуру: все действия выполняются обязательно и в той последовательности, что мы написали их в скрипте. Иногда нам хочется получать разное поведение в зависимости от какого-либо условия.  В этом контексте вам нужно запомнить три ключевых слова: if, else, elif.

# %% [markdown]
# Представим, что мы пишем программу которая будет на основании введенной оценки сообщать студенту, пойдет он на пересдачу по предмету или нет.

# %%
mark = int(input())

if mark >= 4: # если оценка больше или равна 4,
    print('Вы получили удовлетворительную оценку.') # печатаем эту строку
else: # во всех остальных случаях,
    print('Вы получили неудовлетворительную оценку. Вам будет назначена пересдача.') # печатай это

# %% [markdown]
# Вы получили удовлетворительную оценку.
# Но вы также можете использовать ключевое слово elif. Оно используется в ситуациях когда вы хотите использовать несколько условий и усложнить ваш код. Приведем пример:
#
# *   Если оценка студента за предмет меньше 4, он получает пересдачу по этому предмету и теряет стипендию
# *   Если оценка за предмет от 4 до 5 включительно, студент не получает пересдачу, но теряет стипендию
# *   Если оценка 6 и выше, студент не получает пересдачу и сохраняет стипендию.
#
# Программа, сообщающая студенту статус наличия пересдачи и сохранения стипендии, может выглядеть следующим образом:

# %%
mark = int(input()) # вводим значение, преобразуем его в целое число

if mark < 4: # если оценка меньше четырех, печатаем следующее:
    print('Вы получили пересдачу. Вы потеряли право получать стипендию.')
elif mark < 6: # если условие выше не удовлетворено и при этом оценка меньше 6, печатаем следующее:
    print('Вы не получили пересдачу, но потеряли право получать стипендию.')
else: # во всех остальных случаях, печатаем следующее:
    print('Вы не получили пересдачу, и сохранили вашу стипендию.')
# Out:
# 15
# Вы не получили пересдачу, и сохранили вашу стипендию.
# 1

# %% [markdown]
# ### Задача 2
#
# Пользователь вводит температуру (°C) и идет ли дождь (да/нет). Программа советует:
#
# *   Если температура не ниже 20°C и нет дождя: "Наденьте футболку"
# *   Если температура выше 15°C и дождь: "Наденьте дождевик"
# *   Если температура ниже 15°C: "Наденьте куртку"
# *   Иначе: "Смотрите по обстоятельствам"

# %% [markdown]
# ### Задача 3
#
# В математике функция sign(x) (знак числа) определена так:
#
# sign(x) = 1,   если x > 0,
#
# sign(x) = -1, если x < 0,
#
# sign(x) = 0,   если x = 0.
#
# Для данного числа x выведите значение sign(x) в формате: "Было введено число x, его знак sign(x)"

# %% [markdown]
# ### Задача 4
#
# Вводится трехзначное число. Найдите сумму его цифр.

# %% [markdown]
# ### Задача 5
#
# Вводится три целых числа A, B, C каждое в новой строке. Определить, есть ли среди них хотя бы одно четное и хотя бы одно нечетное.

# %% [markdown]
# ## Последнее на сегодня

# %% [markdown]
# * У python есть свои стандартны красоты. Например, ставить пробельчики с двух сторон от арифметических знаков. Это не влияет на исполнение вашего кода, но гораздо упрощает его чтение другому человеку. Прочитать подробнее можно [тут](https://peps.python.org/pep-0008/) (душно, но можно найти более юзерфрендли туториалы и шпаргалки). Учить не стоит, мы будем это упоминать по ходу курса. (*Дисклеймер: в средах разработки есть специальные штуки, которые наводят на код марафет за вас, но наш совет -- приучать себя к PEP8 смолоду.*)
# * Если у вас на компьютере нет python и/или какой-нибудь из сред разработки (VS Code, Pycharm, etc.) обязательно поставьте и если не получится, напишите мне или ассистенту
# * Если вы не поняли что-то с семинара, спрашивайте преподов и ассистентов
# * Если что-то нужно, но вы это не умете и мы про это не сказали на семинаре -- не бойтесь взять и загуглить
